# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
data = pd.read_csv(pwd + '/learn_groupby.csv')
df = data.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637 entries, 0 to 636
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Classification          637 non-null    object
#  1   Year                    637 non-null    int64
#  2   Period                  637 non-null    int64
#  3   Period Desc.            637 non-null    object
#  4   Aggregate Level         637 non-null    int64
#  5   Is Leaf Code            637 non-null    int64
#  6   Trade Flow Code         637 non-null    int64
#  7   Trade Flow              637 non-null    object
#  8   Reporter Code           637 non-null    int64
#  9   Reporter                637 non-null    object
#  10  Reporter ISO            0 non-null      float64
#  11  Partner Code            637 non-null    int64
#  12  Partner                 637 non-null    object
#  13  Partner ISO             0 non-null      float64
# ...

# %%
df.loc[df['Trade Flow'] == 'Exports']
# Out:
#     Classification  Year  Period  Period Desc.  Aggregate Level  Is Leaf Code  \
# 1               HS  2015  201501  January 2015                4             0
# 2               HS  2015  201501  January 2015                4             0
# 3               HS  2015  201501  January 2015                4             0
# 5               HS  2015  201501  January 2015                4             0
# 6               HS  2015  201501  January 2015                4             0
# ..             ...   ...     ...           ...              ...           ...
# 632             HS  2015  201505      May 2015                4             0
# 633             HS  2015  201505      May 2015                4             0
# 634             HS  2015  201505      May 2015                4             0
# 635             HS  2015  201505      May 2015                4             0
# 636             HS  2015  201505      May 2015                4             0
#
# ...

# %%
df.loc[(df['Trade Flow']=='Exports') & (df['Partner']=='Belgium')]
# Out:
#     Classification  Year  Period   Period Desc.  Aggregate Level  \
# 5               HS  2015  201501   January 2015                4
# 53              HS  2015  201502  February 2015                4
# 104             HS  2015  201503     March 2015                4
# 155             HS  2015  201504     April 2015                4
# 211             HS  2015  201505       May 2015                4
# 268             HS  2015  201501   January 2015                4
# 345             HS  2015  201502  February 2015                4
# 426             HS  2015  201503     March 2015                4
# 502             HS  2015  201504     April 2015                4
# 572             HS  2015  201505       May 2015                4
#
#      Is Leaf Code  Trade Flow Code Trade Flow  Reporter Code        Reporter  \
# 5               0                2    Exports            826  United Kingdom
# 53              0                2    Exports            826  United Kingdom
# ...

# %%
df.Partner.unique()
# Out:
# array(['World', 'Australia', 'Austria', 'Belgium', 'Bulgaria', 'Canada',
#        'Sri Lanka', 'China', 'Cyprus', 'Denmark',
#        'Falkland Isds (Malvinas)', 'Finland', 'France', 'Germany',
#        'Greece', 'China, Hong Kong SAR', 'Hungary', 'Ireland', 'Italy',
#        'Latvia', 'Lithuania', 'Malta', 'Oman', 'Netherlands', 'Poland',
#        'Portugal', 'Qatar', 'Romania', 'Singapore', 'South Africa',
#        'Spain', 'Sweden', 'Trinidad and Tobago', 'United Arab Emirates',
#        'United States of America', 'Areas, nes', 'Br. Virgin Isds',
#        'Czech Rep.', 'Dominica', 'Gibraltar', 'Guatemala', 'Kuwait',
#        'Other Asia, nes', 'Saint Helena', 'Sierra Leone', 'Japan',
#        'Rep. of Korea', 'Malaysia', 'Saudi Arabia', 'Ethiopia', 'Guyana',
#        'Equatorial Guinea', 'Guinea', 'Libya', 'Algeria',
#        'Antigua and Barbuda', 'Barbados', 'Cameroon', 'Congo',
#        'Dem.Rep. of the Congo', 'Croatia', 'Benin', 'Gabon', 'Ghana',
# ...

# %%
df.columns
# Out:
# Index(['Classification', 'Year', 'Period', 'Period Desc.', 'Aggregate Level',
#        'Is Leaf Code', 'Trade Flow Code', 'Trade Flow', 'Reporter Code',
#        'Reporter', 'Reporter ISO', 'Partner Code', 'Partner', 'Partner ISO',
#        '2nd Partner Code', '2nd Partner', '2nd Partner ISO',
#        'Customs Proc. Code', 'Customs', 'Mode of Transport Code',
#        'Mode of Transport', 'Commodity Code', 'Commodity', 'Qty Unit Code',
#        'Qty Unit', 'Qty', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty',
#        'Netweight (kg)', 'Gross weight (kg)', 'Trade Value (US$)',
#        'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag'],
#       dtype='object')

# %%
df.loc[0:5,['Trade Flow','Trade Value (US$)']]
# Out:
#   Trade Flow  Trade Value (US$)
# 0    Imports           14104602
# 1    Exports           26259792
# 2    Exports              50331
# 3    Exports                360
# 4    Imports            1424271
# 5    Exports             996031

# %%
df.iloc[0:4,2:8]
# Out:
#    Period  Period Desc.  Aggregate Level  Is Leaf Code  Trade Flow Code  \
# 0  201501  January 2015                4             0                1
# 1  201501  January 2015                4             0                2
# 2  201501  January 2015                4             0                2
# 3  201501  January 2015                4             0                2
#
#   Trade Flow
# 0    Imports
# 1    Exports
# 2    Exports
# 3    Exports

# %%
df.columns.get_loc('Year')
# Out:
# 1

# %%
for x in columnslis:
    return df.columns.get_loc(x)
# Out:
#   Cell In[51], line 2
#     return df.columns.get_loc(x)
#     ^
# SyntaxError: 'return' outside function

# %%
columnslis = ['Classification','Year','Period']

# %%
def unpack(x):
    for n in x:
        print(df.columns.get_loc(n))
        

print(unpack(columnslis))
# Out:
# 0
# 1
# 2
# None

# %%
df.iloc[[1,2]]
df.loc[[0]]
df.iloc[1:5]
df.loc[:,:].head(3)
# Out:
#   Classification  Year  Period  Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             HS  2015  201501  January 2015                4             0
# 1             HS  2015  201501  January 2015                4             0
# 2             HS  2015  201501  January 2015                4             0
#
#    Trade Flow Code Trade Flow  Reporter Code        Reporter  ...  Qty  \
# 0                1    Imports            826  United Kingdom  ...  NaN
# 1                2    Exports            826  United Kingdom  ...  NaN
# 2                2    Exports            826  United Kingdom  ...  NaN
#
#    Alt Qty Unit Code Alt Qty Unit  Alt Qty  Netweight (kg)  Gross weight (kg)  \
# 0                NaN          NaN      NaN        17062015                NaN
# 1                NaN          NaN      NaN        56302663                NaN
# 2                NaN          NaN      NaN           16117                NaN
#
# ...
